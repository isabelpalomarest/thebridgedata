# %% [markdown]
# ## API con token

# %% [markdown]
# _El maravilloso mundo de las_ **APIs**
# ### o EL RETORNO DE JSON

# %% [markdown]
# Listado de **APIs** for free:
# https://github.com/public-apis/public-apis

# %%
import json
import requests

# %%
json_fullpath = "settings_passwords.json"
# settings.json estará en el .gitignore

# %%
with open(json_fullpath, "r+") as outfile:
    json_readed = json.load(outfile)
json_readed
print()

# %% [markdown]
# **DOCUMENTACIÓN DE LA API**
#
#
# --> https://developer.foursquare.com/docs/places-api/ <--
#
# ** Cómo crear una cuenta de desarrollo **
#
# --> https://developer.foursquare.com/docs/places-api/getting-started/ <--
#
# ** Diferentes Endpoints **
#
# --> https://developer.foursquare.com/docs/places-api/endpoints/ <--

# %% [markdown]
# ### Objetivo:
#
# #### Descubrir los restaurantes que están cerca de The Bridge a través de la API de foursquare

# %%
url = 'https://api.foursquare.com/v2/venues/explore'

# más códigos de categorías
# https://developer.foursquare.com/docs/build-with-foursquare/categories/

# irish pub
irish_rest = "52e81612bcbc57f1066b7a06"

# para sacar las coordenadas podrías usar una API pero también...
# https://www.123coordenadas.com/coordinates/

lat = 40.4409422
lon = -3.6780432

# %%
# Lo importante, todas las APIs con token tienen una forma de acceder a ellas. La información pertinente a cada una de ellas viene (o debería venir) en su documentación

params = {"client_id": json_readed["CLIENT"],
  "client_secret": json_readed["API_KEY"],
  "v":"20180323",
  "ll": f'{lat},{lon}',
  "section": "food",
  # options --> food, drinks, coffee, shops, arts, outdoors, sights, trending
  "limit":100
}

# %%
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %%
# Muestra cantidad ilegible de datos

''' data '''
# Out:
# ' data '

# %%
# Para guardar en un archivo local
import pandas as pd
df = pd.DataFrame(data)
df.to_csv("toda_informacion.csv")

# %%
data["response"].keys()
# Out:
# dict_keys(['suggestedFilters', 'suggestedRadius', 'headerLocation', 'headerFullLocation', 'headerLocationGranularity', 'query', 'totalResults', 'suggestedBounds', 'groups'])

# %%
# Cantidad ilegible de datos

data["response"]
# Out:
# ce': 821,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['General Pardiñas 92',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-565ccbce498e5dbdf05e5901-86'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b8a6f15f964a520a26c32e3',
#       'name': 'Marisquería Luis',
#       'contact': {},
#       'location': {'address': 'C. Alonso Heredia',
#        'lat': 40.43608774706164,
#        'lng': -3.672073515253242,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.43608774706164,
#          'lng': -3.672073515253242}],
#        'distance': 740,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Alonso Heredia', 'Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1ce941735',
#         'name': 'Seafood Restaurant',
#         'pluralName': 'Seafood Restaurants',
#         'shortName': 'Seafood',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4b8a6f15f964a520a26c32e3-87'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '52c2d333498eba97bd2472fa',
#       'name': 'El tío Palomo',
#       'contact': {},
#       'location': {'address': 'María Molina, 18',
#        'crossStreet': 'Serrano, 93',
#        'lat': 40.43776,
#        'lng': -3.686659,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.43776,
#          'lng': -3.686659}],
#        'distance': 811,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['María Molina, 18 (Serrano, 93)',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-52c2d333498eba97bd2472fa-88'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4d4bc8e68e948cfa6282f448',
#       'name': 'Restaurante Aylagass',
#       'contact': {},
#       'location': {'address': 'Calle de Castelló, 105-113',
#        'lat': 40.435921445502224,
#        'lng': -3.6806396845645755,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.435921445502224,
#          'lng': -3.6806396845645755}],
#        'distance': 600,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle de Castelló, 105-113',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d150941735',
#         'name': 'Spanish Restaurant',
#         'pluralName': 'Spanish Restaurants',
#         'shortName': 'Spanish',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4d4bc8e68e948cfa6282f448-89'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4e652338a80951b319a768c9',
#       'name': 'Restaurante Palacio de Oriente',
#       'contact': {},
#       'location': {'address': 'Puenteáreas, 19',
#        'lat': 40.44432780459149,
#        'lng': -3.6693957970455022,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.44432780459149,
#          'lng': -3.6693957970455022}],
#        'distance': 823,
#        'postalCode': '28002',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Puenteáreas, 19',
#         '28002 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d145941735',
#         'name': 'Chinese Restaurant',
#         'pluralName': 'Chinese Restaurants',
#         'shortName': 'Chinese',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4e652338a80951b319a768c9-90'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4cf2cc08cfb08eecbc51f0be',
#       'name': 'El Boliche Bacán Restaurante',
#       'contact': {},
#       'location': {'address': 'C/ Diego de León, 56',
#        'lat': 40.434678,
#        'lng': -3.677279,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.434678,
#          'lng': -3.677279}],
#        'distance': 700,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C/ Diego de León, 56',
#         '28006 Salamanca-Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d107941735',
#         'name': 'Argentinian Restaurant',
#         'pluralName': 'Argentinian Restaurants',
#         'shortName': 'Argentinian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4cf2cc08cfb08eecbc51f0be-91'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b9a4c3ef964a52076aa35e3',
#       'name': 'La Armonia',
#       'contact': {},
#       'location': {'address': 'Calle del General Oráa, 18',
#        'lat': 40.436261290370666,
#        'lng': -3.684830284212933,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.436261290370666,
#          'lng': -3.684830284212933}],
#        'distance': 776,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle del General Oráa, 18',
#         'Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d16d941735',
#         'name': 'Café',
#         'pluralName': 'Cafés',
#         'shortName': 'Café',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4b9a4c3ef964a52076aa35e3-92'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4e945a6d0cd61c757e5b74be',
#       'name': 'Do Eat!',
#       'contact': {},
#       'location': {'address': 'C. de María de Molina, 18',
#        'crossStreet': 'C. de Serrano',
#        'lat': 40.437793648066624,
#        'lng': -3.6869486862253575,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.437793648066624,
#          'lng': -3.6869486862253575}],
#        'distance': 831,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. de María de Molina, 18 (C. de Serrano)',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1bd941735',
#         'name': 'Salad Place',
#         'pluralName': 'Salad Places',
#         'shortName': 'Salad',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4e945a6d0cd61c757e5b74be-93'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4e218d91c65b2b5e3547707c',
#       'name': 'Taberna Del Puerto',
#       'contact': {},
#       'location': {'lat': 40.43467612833083,
#        'lng': -3.6769463950842876,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.43467612833083,
#          'lng': -3.6769463950842876}],
#        'distance': 703,
#        'cc': 'ES',
#        'country': 'España',
#        'formattedAddress': ['España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4e218d91c65b2b5e3547707c-94'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b6725cbf964a520bb3d2be3',
#       'name': 'Chikito',
#       'contact': {},
#       'location': {'address': 'Calle Diego de León, 20',
#        'crossStreet': 'Calle Velázquez',
#        'lat': 40.43492514285718,
#        'lng': -3.6833636326648374,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.43492514285718,
#          'lng': -3.6833636326648374}],
#        'distance': 807,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle Diego de León, 20 (Calle Velázquez)',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d155941735',
#         'name': 'Gastropub',
#         'pluralName': 'Gastropubs',
#         'shortName': 'Gastropub',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '67039434'},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4b6725cbf964a520bb3d2be3-95'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '587a90b016f0004ec8b02507',
#       'name': 'Bo Wok',
#       'contact': {},
#       'location': {'lat': 40.44485,
#        'lng': -3.6731822,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.44485,
#          'lng': -3.6731822}],
#        'distance': 599,
#        'postalCode': '28002',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['28002 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d142941735',
#         'name': 'Asian Restaurant',
#         'pluralName': 'Asian Restaurants',
#         'shortName': 'Asian',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-587a90b016f0004ec8b02507-96'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5299cbb6498e496639c427bb',
#       'name': 'Cotico',
#       'contact': {},
#       'location': {'address': 'Diego De León 63',
#        'lat': 40.434566225664454,
#        'lng': -3.675830025451954,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.434566225664454,
#          'lng': -3.675830025451954}],
#        'distance': 734,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Diego De León 63', 'Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-5299cbb6498e496639c427bb-97'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b9b8cb0f964a520b70e36e3',
#       'name': 'Telepizza',
#       'contact': {},
#       'location': {'address': 'Corazón de María, 9',
#        'lat': 40.44263355833711,
#        'lng': -3.6716002142407973,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.44263355833711,
#          'lng': -3.6716002142407973}],
#        'distance': 577,
#        'postalCode': '28002',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Corazón de María, 9',
#         '28002 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1ca941735',
#         'name': 'Pizza Place',
#         'pluralName': 'Pizza Places',
#         'shortName': 'Pizza',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-4b9b8cb0f964a520b70e36e3-98'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '526c0f9811d24f04f6c29649',
#       'name': 'Madcooking Kitchen & Bar',
#       'contact': {},
#       'location': {'address': 'C. Suero de Quiñones, 18',
#        'lat': 40.4451004196237,
#        'lng': -3.6764859797403915,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.4451004196237,
#          'lng': -3.6764859797403915}],
#        'distance': 481,
#        'postalCode': '28002',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Suero de Quiñones, 18',
#         '28002 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1c4941735',
#         'name': 'Restaurant',
#         'pluralName': 'Restaurants',
#         'shortName': 'Restaurant',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '355098362'},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-3-526c0f9811d24f04f6c29649-99'}]}]}

# %%
data["response"]['groups'][0].keys()
# Out:
# dict_keys(['type', 'name', 'items'])

# %%
data["response"]['groups'][0]["items"][0].keys()
# Out:
# dict_keys(['reasons', 'venue', 'referralId'])

# %%
data["response"]['groups'][0]["items"][0]["venue"]
# Out:
# {'id': '5499d2c1498e29e8a630cf12',
#  'name': 'Miki',
#  'contact': {},
#  'location': {'address': 'Duque de Sevilla 4',
#   'lat': 40.44196713110575,
#   'lng': -3.6793412744388974,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.44196713110575,
#     'lng': -3.6793412744388974}],
#   'distance': 158,
#   'cc': 'ES',
#   'city': 'Madrid Centro, Madrid',
#   'state': 'Madrid',
#   'country': 'España',
#   'formattedAddress': ['Duque de Sevilla 4',
#    'Madrid Centro Madrid',
#    'España']},
#  'categories': [{'id': '4bf58dd8d48988d1d2941735',
#    'name': 'Sushi Restaurant',
#    'pluralName': 'Sushi Restaurants',
#    'shortName': 'Sushi',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 0,
#   'usersCount': 0,
#   'checkinsCount': 0,
#   'visitsCount': 0},
#  'beenHere': {'count': 0,
#   'lastCheckinExpiredAt': 0,
#   'marked': False,
#   'unconfirmedCount': 0},
#  'photos': {'count': 0, 'groups': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}}

# %%
data["response"]['groups'][0]["items"][0]["venue"]['name']
# Out:
# 'Miki'

# %%
for rest in data["response"]['groups'][0]["items"]:
    print(rest["venue"]["name"])
# Out:
# Miki
# Urrechu Velázquez
# Bar Alonso
# Chiquito Riz
# O'Buraco
# Panaria
# Yamate
# Honest Greens
# Lobbo
# Mi Taska Bar
# Kitchen Club
# Faborit
# Marisquería Salamar
# Al Fanus
# La Vaca Argentina
# Chocolatería San Ginés
# Pollos Asados
# El Txacolí
# Panadario
# Hermanos Ordás
# Sagar Indian Cuisine
# Restaurante Rías Bajas
# Ronda 14
# La Tagliatella
# La Maragata
# Terraza Lobbo
# Rincon de Pardiñas
# 29 Fanegas
# Don Lay
# Chocolatería Milagros
# Goiko Grill
# Vila Brasil
# Taberna Aránzazu
# Taberna Vella Cardeño
# Tierra Burrito Bar
# El Colmado de Jose Picón
# Restaurante Masterchef
# Villoldo
# Granier
# Doli
# Surtopía
# The Warehouse
# Starbucks Velázquez
# Casa Club
# Marisquería Norte Y Sur
# Nájera Plus
# Fitz Burger
# La Garriga
# Cartagena 93
# La Ermita del Pintxo
# Cazorla
# yakuza
# Lamucca
# La Tagliatella
# La Bóveda 78
# La Taberna del Cardenal
# Mexican Factory Burrito Bar
# Rugantino "Casa Tua"
# Reblochón
# El Coto Del Casar
# Wok Garden
# Casa Sushi
# Pizzería 2 Amigos
# LaKuntza
# Saona
# Bangalore Madrid
# Timesburg
# The Hall
# Evboca
# Simply to go by Sodexo
# Ve-gá Bar
# DDiego
# Bar Carlos
# José Luis
# tanteo
# Telepizza
# Ginos Velázquez
# Uvepan
# La Quinta
# Bar Veracruz
# Abuelita Alicia
# Casa Jorge
# Itacho Sushi
# Taberna del Volapié
# Panxon
# Santagloria
# Txirimiri
# Marisquería Luis
# El tío Palomo
# Restaurante Aylagass
# Restaurante Palacio de Oriente
# El Boliche Bacán Restaurante
# La Armonia
# Do Eat!
# Taberna Del Puerto
# Chikito
# Bo Wok
# Cotico
# Telepizza
# Madcooking Kitchen & Bar

# %%
opciones = [rest["venue"]["name"] for rest in data["response"]['groups'][0]["items"]]
opciones
# Out:
# ['Miki',
#  'Urrechu Velázquez',
#  'Bar Alonso',
#  'Chiquito Riz',
#  "O'Buraco",
#  'Panaria',
#  'Yamate',
#  'Honest Greens',
#  'Lobbo',
#  'Mi Taska Bar',
#  'Kitchen Club',
#  'Faborit',
#  'Marisquería Salamar',
#  'Al Fanus',
#  'La Vaca Argentina',
#  'Chocolatería San Ginés',
#  'Pollos Asados',
#  'El Txacolí',
#  'Panadario',
#  'Hermanos Ordás',
#  'Sagar Indian Cuisine',
#  'Restaurante Rías Bajas',
#  'Ronda 14',
#  'La Tagliatella',
#  'La Maragata',
#  'Terraza Lobbo',
#  'Rincon de Pardiñas',
#  '29 Fanegas',
#  'Don Lay',
#  'Chocolatería Milagros',
#  'Goiko Grill',
#  'Vila Brasil',
#  'Taberna Aránzazu',
#  'Taberna Vella Cardeño',
#  'Tierra Burrito Bar',
#  'El Colmado de Jose Picón',
#  'Restaurante Masterchef',
#  'Villoldo',
#  'Granier',
#  'Doli',
#  'Surtopía',
#  'The Warehouse',
#  'Starbucks Velázquez',
#  'Casa Club',
#  'Marisquería Norte Y Sur',
#  'Nájera Plus',
#  'Fitz Burger',
#  'La Garriga',
#  'Cartagena 93',
#  'La Ermita del Pintxo',
#  'Cazorla',
#  'yakuza',
#  'Lamucca',
#  'La Tagliatella',
#  'La Bóveda 78',
#  'La Taberna del Cardenal',
#  'Mexican Factory Burrito Bar',
#  'Rugantino "Casa Tua"',
#  'Reblochón',
#  'El Coto Del Casar',
#  'Wok Garden',
#  'Casa Sushi',
#  'Pizzería 2 Amigos',
#  'LaKuntza',
#  'Saona',
#  'Bangalore Madrid',
#  'Timesburg',
#  'The Hall',
#  'Evboca',
#  'Simply to go by Sodexo',
#  'Ve-gá Bar',
#  'DDiego',
#  'Bar Carlos',
#  'José Luis',
#  'tanteo',
#  'Telepizza',
#  'Ginos Velázquez',
#  'Uvepan',
#  'La Quinta',
#  'Bar Veracruz',
#  'Abuelita Alicia',
#  'Casa Jorge',
#  'Itacho Sushi',
#  'Taberna del Volapié',
#  'Panxon',
#  'Santagloria',
#  'Txirimiri',
#  'Marisquería Luis',
#  'El tío Palomo',
#  'Restaurante Aylagass',
#  'Restaurante Palacio de Oriente',
#  'El Boliche Bacán Restaurante',
#  'La Armonia',
#  'Do Eat!',
#  'Taberna Del Puerto',
#  'Chikito',
#  'Bo Wok',
#  'Cotico',
#  'Telepizza',
#  'Madcooking Kitchen & Bar']

# %% [markdown]
# Comprobamos que efectivamente están cerca de **The Bridge**

# %% [markdown]
# - **Charrua**

# %% [markdown]
# https://www.google.com/maps/place/Charr%C3%BAa+Madrid/@40.4213206,-3.6974034,15z/data=!4m5!3m4!1s0x0:0x8673b16903da6e51!8m2!3d40.4223987!4d-3.6940989

# %% [markdown]
# - **Pelotari**

# %% [markdown]
# https://www.google.com/maps/place/Pelotari/@40.4210322,-3.7011421,15.06z/data=!4m8!1m2!2m1!1spelotari!3m4!1s0xd42289a8d2d74cb:0x2b6420709612ce53!8m2!3d40.4222232!4d-3.6906525

# %% [markdown]
# - **Doki doki**

# %% [markdown]
# https://www.google.com/maps/place/Restaurante+Doki+Doki/@40.421046,-3.6919977,17z/data=!3m1!4b1!4m5!3m4!1s0xd42289a5313ac17:0x27cfb02077407a64!8m2!3d40.421046!4d-3.689809
