# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# MPG: Millas por galón
# MSRP: Precio de venta

df = pd.read_csv("HP_engine.csv")
df.sample(10)
# Out:
#              Make                   Model  Year  \
# 7115        Mazda              MX-5 Miata  2015
# 9438    Chevrolet  Silverado 1500 Classic  2007
# 3719   Volkswagen                  e-Golf  2016
# 6327   Mitsubishi        Lancer Sportback  2014
# 2142          Kia                 Cadenza  2015
# 11774    Cadillac                     XTS  2016
# 11873         GMC                   Yukon  2016
# 7198   Volkswagen              New Beetle  2008
# 7523       Nissan              Pathfinder  2015
# 3743         Ford          E-Series Wagon  2012
#
#                      Engine Fuel Type  Engine HP  Engine Cylinders  \
# 7115   premium unleaded (recommended)      158.0               4.0
# 9438                 regular unleaded      295.0               8.0
# 3719                         electric      115.0               NaN
# 6327                 regular unleaded      168.0               4.0
# 2142                 regular unleaded      293.0               6.0
# 11774                regular unleaded      304.0               6.0
# 11873        flex-fuel (unleaded/E85)      355.0               8.0
# 7198                 regular unleaded      150.0               5.0
# 7523                 regular unleaded      260.0               6.0
# 3743         flex-fuel (unleaded/E85)      255.0               8.0
#
#       Transmission Type      Driven_Wheels  Number of Doors  \
# 7115          AUTOMATIC   rear wheel drive              2.0
# 9438          AUTOMATIC   four wheel drive              4.0
# 3719       DIRECT_DRIVE  front wheel drive              4.0
# 6327          AUTOMATIC  front wheel drive              4.0
# 2142          AUTOMATIC  front wheel drive              4.0
# 11774         AUTOMATIC  front wheel drive              4.0
# 11873         AUTOMATIC   rear wheel drive              4.0
# 7198             MANUAL  front wheel drive              2.0
# 7523          AUTOMATIC  front wheel drive              4.0
# 3743          AUTOMATIC   rear wheel drive              3.0
#
#              Market Category Vehicle Size        Vehicle Style  highway MPG  \
# 7115             Performance      Compact          Convertible           28
# 9438                     NaN        Large  Extended Cab Pickup           18
# 3719               Hatchback      Compact        4dr Hatchback          105
# 6327               Hatchback      Compact        4dr Hatchback           29
# 2142             Performance      Midsize                Sedan           28
# 11774     Luxury,Performance        Large                Sedan           28
# 11873  Flex Fuel,Performance        Large              4dr SUV           23
# 7198                     NaN      Compact          Convertible           28
# 7523               Crossover        Large              4dr SUV           27
# 3743               Flex Fuel      Midsize        Passenger Van           15
#
#        city mpg  Popularity   MSRP
# 7115         21         586  30550
# 9438         13        1385  31375
# 3719        126         873  35595
# 6327         22         436  21945
# 2142         19        1720  34900
# 11774        18        1624  45295
# 11873        16         549  48315
# 7198         20         873  23240
# 7523         20        2009  33140
# 3743         11        5657  31855

# %%
df.shape
# Out:
# (11914, 16)

# %%
# Correlación de Pearson
# -1 < r < 1

# Finding the relations between the variables.
plt.figure(figsize=(15,10))
c = df.corr()
sns.heatmap(c, cmap="BrBG",annot=True)
c
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.351794         -0.041479         0.263787
# Engine HP         0.351794   1.000000          0.779988        -0.102713
# Engine Cylinders -0.041479   0.779988          1.000000        -0.140088
# Number of Doors   0.263787  -0.102713         -0.140088         1.000000
# highway MPG       0.258240  -0.406563         -0.621606         0.118570
# city mpg          0.198171  -0.439371         -0.600776         0.120881
# Popularity        0.073049   0.037501          0.041145        -0.048272
# MSRP              0.227590   0.662008          0.531312        -0.126635
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.258240  0.198171    0.073049  0.227590
# Engine HP           -0.406563 -0.439371    0.037501  0.662008
# Engine Cylinders    -0.621606 -0.600776    0.041145  0.531312
# Number of Doors      0.118570  0.120881   -0.048272 -0.126635
# highway MPG          1.000000  0.886829   -0.020991 -0.160043
# city mpg             0.886829  1.000000   -0.003217 -0.157676
# Popularity          -0.020991 -0.003217    1.000000 -0.048476
# MSRP                -0.160043 -0.157676   -0.048476  1.000000

# %% [markdown]
# Correlación positiva --> (>0.5)
#
# Correlación negativa --> (<-0.45)

# %%
df.corr()
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.351794         -0.041479         0.263787
# Engine HP         0.351794   1.000000          0.779988        -0.102713
# Engine Cylinders -0.041479   0.779988          1.000000        -0.140088
# Number of Doors   0.263787  -0.102713         -0.140088         1.000000
# highway MPG       0.258240  -0.406563         -0.621606         0.118570
# city mpg          0.198171  -0.439371         -0.600776         0.120881
# Popularity        0.073049   0.037501          0.041145        -0.048272
# MSRP              0.227590   0.662008          0.531312        -0.126635
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.258240  0.198171    0.073049  0.227590
# Engine HP           -0.406563 -0.439371    0.037501  0.662008
# Engine Cylinders    -0.621606 -0.600776    0.041145  0.531312
# Number of Doors      0.118570  0.120881   -0.048272 -0.126635
# highway MPG          1.000000  0.886829   -0.020991 -0.160043
# city mpg             0.886829  1.000000   -0.003217 -0.157676
# Popularity          -0.020991 -0.003217    1.000000 -0.048476
# MSRP                -0.160043 -0.157676   -0.048476  1.000000

# %%
sns.heatmap(df.corr(), cmap="BrBG", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Correlación de Pearson
# #### -1 < r < 1
# ![](correlation-examples.svg)
